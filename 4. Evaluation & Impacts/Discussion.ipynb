# %% [markdown]
# Part C (40%) Discussion (3x A4 page max)
# 1. Assess the impact of your model on the individual, society and the environment. (1 A4 page max)
# 2. Discuss how patterns in human behaviour may influence your model
# 3. Discuss bias in relation to your model
