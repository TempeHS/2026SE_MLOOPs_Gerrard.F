# %% [markdown]
# ## Design
#
# #### **Defining Business Problem**
#
# Valorant is a popular game with large-player base that spans globally. With majority of players being stuck in what's defined as 'low-elo' meaning lobbies that mainly have players who are new to the game, excuses and emotions tend to uprise with no proper explanation as to why they are losing. Is it the teammates, the game or you? In Valorant there is a hidden measurement defined as 'MMR' or Match-making Rating this determines the type of teammates and enemies that you are paired against, although there is no proper way to check.
#
# With this opportunity I have identified the potential to create an AI model that is able to assess your MMR based off of your performance. This will allow for a public representation of MMR and for people to be able to identify whether it's a personal issue or their teammates. This model will have to be careful of interpretative bias as players may feel dis-encouraged or misunderstand data, potentially blaming or out-lashing on the community. This should be a small scale model that uses Neural Networks to train patterns based off of user inputs, hopefully allowing for me to remove prior data entries to protect privacy and save computation power.

# %% [markdown]
# #### **Convert Business Problem into Machine Learning Problem**
#
# Allow for users to be able to interpret their ability to efficiently increase their rank and improvements that can be made to their gameplay
#
# Predict MMR through Neural Networks based off of Model of RR
#
# Allow for users to predict/interpret their MMR and opens critiques to the game design
# Users should be able to input their own data

# %% [markdown]
# #### **Defining Success Metrics**
#
# There are miniscule factors that can skew data such as data from your team and enemy team (unfair matchmaking, hackers) and also an MMR measurement that is hidden and thus can only be predicted based off of RR as it scales your RR dependent on your skill.
#
# The hidden mechanic of MMR fluctuates dependent on a various variables thus the best way to get an accurate description of MMR is to take data from all ranks within the game as different people receive different teammates, have different habits and capabilities then use specifically only “solo queue” data as queueing with teammates can affect RR meaning that I want the fairest data possible with least amount of interference
#
# Econ is an optional feature however it takes into account the ability of the user to utilise available weapons and capitalise off of that in game, thus a high econ means a user is able to win with less deaths or worse guns potentially correlating to a player’s skill
#
# I must feature engineer certain data as there’s a clear relationship between certain features and be combining them
#
# I simplify it for the machine whilst also making a more ideal relationship/feature
#
# MMR is specific to individual players thus by grabbing a majority of different data the MMR value will be generalised allowing for the model to calculate a better prediction lowering variance
