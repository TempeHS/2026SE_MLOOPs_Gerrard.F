# %% [markdown]
# # Downloading data

# %%
from urllib.request import urlretrieve 
import os

try:
    os.mkdir("dl")
raise:
    pass

urlretrieve(
    "https://raw.githubusercontent.com/TharunThomas8/tracker.gg-web-scraping/refs/heads/main/data/valo_data_all.csv",
    "dl/dataset.csv"
)
